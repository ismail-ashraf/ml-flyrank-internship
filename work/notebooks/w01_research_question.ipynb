# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# **I chose the Growth / Recovery / Momentum Prediction lane because I want to investigate whether historical search-performance signals can help identify pages that are likely to improve or decline in the future. If these patterns can be identified early, they may help content and SEO teams prioritize their work before performance changes become significant.**

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

from IPython.core.pylabtools import figsize
from fontTools.varLib.instancer import verticalMetricsKeptInSync

print(os.getcwd())
# Out:
# C:\Users\abdel\ml-flyrank-internship\work\notebooks

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# ## *Research Question
#
# Which pages are likely to experience growth or decline in search performance during the next reporting period?
#
# ## *Decision
#
# The project supports SEO and content teams in deciding which pages should be monitored or improved first.
#
# ##*Action
#
# If a page is predicted to decline, the team can review and update its content, metadata, or technical SEO before performance drops further. If a page is expected to grow, the team can reinforce its strengths and monitor its progress.
#
# ## *Cost of a Wrong Recommendation
#
# An incorrect recommendation may cause the team to spend time improving pages that do not need attention while overlooking pages that are actually at risk of losing traffic. This could reduce the effectiveness of SEO efforts and waste limited resources.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *The starter dataset contains **30,000 content pages**, providing enough observations for meaningful analysis.
#
# Among these pages, **16,262 are currently labeled as "down"**, while only **4,388 are labeled as "up"**, suggesting that performance decline is a common pattern worth investigating.
#
# In addition, only **1,078 pages** fall into the "excellent" impression tier, while **11,248 pages** are in the "low" tier, indicating substantial variation in search performance across the dataset. These observations support investigating whether historical signals can help identify pages that are likely to improve or decline.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import pandas as pd
print(os.listdir('../../data/raw'))

df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')
df.head()
# Out:
# ['content_refresh_anonymized.csv']
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.columns.tolist()
# Out:
# ['content_id',
#  'client_id',
#  'search_volume',
#  'competition',
#  'competition_level',
#  'cpc',
#  'content_type',
#  'main_intent',
#  'word_count',
#  'char_count',
#  'provider_used',
#  'model_used',
#  'impressions_90d',
#  'clicks_90d',
#  'pageviews_90d',
#  'sessions_90d',
#  'users_90d',
#  'engaged_sessions_90d',
#  'ai_sessions_90d',
#  'scroll_events_90d',
#  'days_with_impressions',
#  'days_with_sessions',
#  'impressions_last_30d',
#  'clicks_last_30d',
#  'sessions_last_30d',
#  'impressions_prev_30d',
#  'clicks_prev_30d',
#  'sessions_prev_30d',
#  'content_age_days',
#  'age_tier',
#  'age_tier_order',
#  'days_since_last_update',
#  'freshness_tier',
#  'word_count_tier',
#  'char_count_tier',
#  'ctr',
#  'avg_position',
#  'engagement_rate',
#  'scroll_rate',
#  'ai_traffic_pct',
#  'impression_tier',
#  'position_tier',
#  'trend_direction',
#  'trend_pct']

# %% [markdown]
# # **First Number**

# %%
df['trend_direction'].value_counts()
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64

# %% [markdown]
# #  **Second Number**

# %%
df['ctr'].describe()
# Out:
# count    30000.000000
# mean         0.510733
# std          3.279162
# min          0.000000
# 25%          0.000000
# 50%          0.070000
# 75%          0.290000
# max        100.000000
# Name: ctr, dtype: float64

# %% [markdown]
#  # **Third Number**

# %%
df['impression_tier'].value_counts()
# Out:
# impression_tier
# low          11248
# moderate     10469
# good          7205
# excellent     1078
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project aims to identify patterns in historical search-performance data that may help support future content decisions. Any predictions will be based only on the available data and should be considered decision-support rather than certainty.
#
# This work cannot prove why a page grows or declines, and it cannot predict Google's ranking decisions with certainty. It only measures patterns observed in the available dataset.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
